# %%
import patient as p
import tensorflow as tf
import numpy as np
import myLib
import consts as c

# %%
c.WINDOW_SIZE = 15
tabSegments =  []
for pStr in c.trainPatients:
    patient = p.patient(pStr)
    pos = patient.getPositveSegmentsAdvanced()
    neg = patient.getNegativesN(len(pos))
    tabSegments = tabSegments + pos + neg # add positves
    #tabSegments = tabSegments + patient.getNegativesN(len(tabSegments[-1][0]))
    


x_train,y_train = myLib.processDF(tabSegments)

x_test,y_test,x_validation,y_validation = myLib.getTrainValData()

# %%
from lazypredict.Supervised import LazyRegressor

clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [26:24<00:00, 37.71s/it]
#                                       Adjusted R-Squared  \
# Model
# SGDRegressor                  35580092831754323230720.00
# Lars                                          1399980.99
# TransformedTargetRegressor                          1.04
# LinearRegression                                    1.04
# PassiveAggressiveRegressor                          1.04
# KernelRidge                                         1.04
# SVR                                                 1.03
# NuSVR                                               1.03
# GaussianProcessRegressor                            1.02
# HuberRegressor                                      1.02
# LinearSVR                                           1.02
# MLPRegressor                                        1.02
# KNeighborsRegressor                                 1.02
# GradientBoostingRegressor                           1.01
# DecisionTreeRegressor                               1.01
# HistGradientBoostingRegressor                       1.01
# OrthogonalMatchingPursuit                           1.01
# BaggingRegressor                                    1.01
# LGBMRegressor                                       1.01
# RandomForestRegressor                               1.01
# Ridge                                               1.01
# OrthogonalMatchingPursuitCV                         1.01
# RidgeCV                                             1.01
# AdaBoostRegressor                                   1.01
# BayesianRidge                                       1.01
# Lasso                                               1.01
# ExtraTreeRegressor                                  1.01
# ElasticNet                                          1.01
# DummyRegressor                                      1.01
# LassoLars                                           1.01
# GeneralizedLinearRegressor                          1.01
# TweedieRegressor                                    1.01
# XGBRegressor                                        1.01
# LassoCV                                             1.01
# ElasticNetCV                                        1.01
# LassoLarsCV                                         1.01
# LassoLarsIC                                         1.01
# LarsCV                                              1.01
# ExtraTreesRegressor                                 1.01
# PoissonRegressor                                    1.01
#
#                                                   R-Squared            RMSE  \
# Model
# SGDRegressor                  -3565499829034749089808384.00 944126557861.12
# Lars                                          -140292730.95         5922.26
# TransformedTargetRegressor                            -3.42            1.05
# LinearRegression                                      -3.42            1.05
# PassiveAggressiveRegressor                            -3.09            1.01
# KernelRidge                                           -2.52            0.94
# SVR                                                   -1.89            0.85
# NuSVR                                                 -1.75            0.83
# GaussianProcessRegressor                              -1.00            0.71
# HuberRegressor                                        -0.99            0.71
# LinearSVR                                             -0.83            0.68
# MLPRegressor                                          -0.65            0.64
# KNeighborsRegressor                                   -0.58            0.63
# GradientBoostingRegressor                             -0.42            0.60
# DecisionTreeRegressor                                 -0.40            0.59
# HistGradientBoostingRegressor                         -0.26            0.56
# OrthogonalMatchingPursuit                             -0.24            0.56
# BaggingRegressor                                      -0.21            0.55
# LGBMRegressor                                         -0.18            0.54
# RandomForestRegressor                                 -0.16            0.54
# Ridge                                                 -0.08            0.52
# OrthogonalMatchingPursuitCV                           -0.06            0.52
# RidgeCV                                               -0.04            0.51
# AdaBoostRegressor                                     -0.03            0.51
# BayesianRidge                                         -0.00            0.50
# Lasso                                                  0.00            0.50
# ExtraTreeRegressor                                     0.00            0.50
# ElasticNet                                             0.00            0.50
# DummyRegressor                                         0.00            0.50
# LassoLars                                              0.00            0.50
# GeneralizedLinearRegressor                             0.01            0.50
# TweedieRegressor                                       0.01            0.50
# XGBRegressor                                           0.02            0.50
# LassoCV                                                0.02            0.50
# ElasticNetCV                                           0.02            0.50
# LassoLarsCV                                            0.02            0.49
# LassoLarsIC                                            0.04            0.49
# LarsCV                                                 0.05            0.49
# ExtraTreesRegressor                                    0.05            0.49
# PoissonRegressor                                       0.14            0.46
#
#                                Time Taken
# Model
# SGDRegressor                         0.49
# Lars                                12.01
# TransformedTargetRegressor           2.49
# LinearRegression                     2.60
# PassiveAggressiveRegressor           0.26
# KernelRidge                          0.37
# SVR                                  3.71
# NuSVR                                4.99
# GaussianProcessRegressor             7.30
# HuberRegressor                       2.35
# LinearSVR                            7.47
# MLPRegressor                         2.74
# KNeighborsRegressor                  0.83
# GradientBoostingRegressor           76.05
# DecisionTreeRegressor                2.30
# HistGradientBoostingRegressor       30.53
# OrthogonalMatchingPursuit            0.48
# BaggingRegressor                    11.77
# LGBMRegressor                       18.40
# RandomForestRegressor              110.78
# Ridge                                0.34
# OrthogonalMatchingPursuitCV          1.64
# RidgeCV                              1.28
# AdaBoostRegressor                    6.69
# BayesianRidge                        7.83
# Lasso                                0.23
# ExtraTreeRegressor                   0.51
# ElasticNet                           0.23
# DummyRegressor                       0.17
# LassoLars                            0.26
# GeneralizedLinearRegressor           0.32
# TweedieRegressor                     0.30
# XGBRegressor                        22.42
# LassoCV                            616.55
# ElasticNetCV                       498.64
# LassoLarsCV                         48.57
# LassoLarsIC                         12.74
# LarsCV                              36.21
# ExtraTreesRegressor                 30.52
# PoissonRegressor                     0.31
