# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[np.NAN,2,np.NAN,3,2],[5,2,np.NAN,np.NAN,2],[6,3,np.NAN,np.NAN,9]])

df
# Out:
#      0  1   2    3  4
# 0  NaN  2 NaN  3.0  2
# 1  5.0  2 NaN  NaN  2
# 2  6.0  3 NaN  NaN  9

# %%
df.fillna(method="backfill").fillna(method="ffill").fillna(0)
# Out:
#      0  1    2    3  4
# 0  5.0  2  0.0  3.0  2
# 1  5.0  2  0.0  3.0  2
# 2  6.0  3  0.0  3.0  9

# %%
import patient as p
import consts as c

c.WINDOW_SIZE = c.PREPREDICTION_LENGTH + 5
tabSegments = []
for pStr in c.trainPatients:
    patient = p.patient(pStr)
    pos = patient.getPositveSegmentsAdvanced()
    neg = patient.getNegativesN(len(pos))
    tabSegments = tabSegments + pos + neg # add positves
    #tabSegments = tabSegments + patient.getNegativesN(len(tabSegments[-1][0]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1464/1814995722.py in <module>
#       6 for pStr in c.trainPatients:
#       7     patient = p.patient(pStr)
# ----> 8     pos = patient.getPositveSegmentsAdvanced()
#       9     neg = patient.getNegativesN(len(pos))
#      10     tabSegments = tabSegments + pos + neg # add positves
#
# c:\DEV\P3\epilepticseizuredetection\patient.py in getPositveSegmentsAdvanced(self)
#      90             for ts in range(startTS,stopTS,consts.POSTIVE_EXTRACT_INTERVAL * 1000):
#      91                 #print(f"{i} {ts}")
# ---> 92                 df = self.getSegmentFromChannels(ts)
#      93                 if df is not None:
#      94                     tabSegments.append((df, 1))
#
# c:\DEV\P3\epilepticseizuredetection\patient.py in getSegmentFromChannels(self, ts)
#      41         buildDF = pd.DataFrame()
# ...

# %%
shapes = [(x.shape,t) for x,t in tabSegments]
setShape = list(set(shapes))
setShape

# %%
print(f"{tabSegments[10][0].shape} == {setShape[0][0]} = {tabSegments[10][0].shape == setShape[0][0]}")

# %%
indices = [i for i,x in enumerate(tabSegments) if tabSegments[i][0].shape == setShape[3][0] or tabSegments[i][0].shape == setShape[1][0]]
indices

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
#display(tabSegments[indices[0]-2][0])
tabSegments[0][0]
#nans = [x for x in tabSegments if pd.isna(x[0])]

# %%
import channel

c = channel.channel("MSEL_01808", "Empatica-EDA", "EDA")
df = c.getData(c.fromS2TS(5000),c.fromS2TS(5000+20))
len(df)
